x94G\x00\x00\x00\x00\x00\x00\x00\x00\x8c\x03dec\x94G\x00\x00\x00\x00\x00\x00\x00\x00u\x8c\x0bspecextract\x94}\x94(\x8c\x07bkgfile\x94N\x8c\x03asp\x94N\x8c\x07dtffile\x94N\x8c\x07mskfile\x94N\x8c\x07rmffile\x94\x8c\x05CALDB\x94\x8c\nbadpixfile\x94N\x8c\x06dafile\x94\x8c\x05CALDB\x94\x8c\x07bkgresp\x94\x88\x8c\x06weight\x94\x88\x8c\nweight_rmf\x94\x89\x8c\x08refcoord\x94N\x8c\ncorrectpsf\x94\x89\x8c\x07combine\x94\x89\x8c\x12readout_streakspec\x94\x89\x8c\tgrouptype\x94\x8c\x07NUM_CTS\x94\x8c\x07binspec\x94\x8c\x0215\x94\x8c\rbkg_grouptype\x94\x8c\x04NONE\x94\x8c\x0bbkg_binspec\x94N\x8c\x06energy\x94\x8c\r0.3:11.0:0.01\x94\x8c\x07channel\x94\x8c\x081:1024:1\x94\x8c\x0benergy_wmap\x94\x8c\x08300:2000\x94\x8c\nbinarfcorr\x94\x8c\x011\x94\x8c\x07binwmap\x94\x8c\x06tdet=8\x94\x8c\nbinarfwmap\x94j/\x01\x00\x00\x8c\x08parallel\x94\x88\x8c\x05nproc\x94N\x8c\x06tmpdir\x94\x8c\x12${ASCDS_WORK_PATH}\x94\x8c\x07clobber\x94\x88\x8c\x07verbose\x94K\x01uu\x8c\x08saotrace\x94}\x94(\x8c\x03tag\x94\x8c\x03foo\x94\x8c\x07srcpars\x94\x8c\x07src.lua\x94\x8c\x06shells\x94\x8c\x03all\x94\x8c\x06tstart\x94G\x00\x00\x00\x00\x00\x00\x00\x00\x8c\x01z\x94G@\xc3\xaf\xe3\x12n\x97\x8d\x8c\x03src\x94\x8c\x07default\x94\x8c\x06output\x94\x8c\x07default\x94\x8c\noutput_fmt\x94\x8c\tfits-axaf\x94\x8c\x0coutput_coord\x94\x8c\x04hrma\x94\x8c\routput_fields\x94\x8c\x03min\x94\x8c\nlimit_type\x94\x8c\x03sec\x94\x8c\x05seed1\x94K\x01\x8c\x05seed2\x94K\x01\x8c\x05block\x94K\x00\x8c\tblock_inc\x94Kd\x8c\x05focus\x94\x8c\x02no\x94\x8c\x05tally\x94K\x00\x8c\x08throttle\x94J\xff\xff\xff\xff\x8c\x10throttle_poisson\x94\x8c\x02no\x94\x8c\nconfig_dir\x94\x8c\x18${SAOTRACE_DB}/ts_config\x94\x8c\tconfig_db\x94\x8c\x12orbit-200809-01f-a\x94\x8c\x05clean\x94\x8c\x03all\x94\x8c\x05debug\x94]\x94\x8c\x00\x94a\x8c\x04help\x94\x8c\x02no\x94\x8c\x07version\x94\x8c\x02no\x94\x8c\x04mode\x94\x8c\x01a\x94\x8c\x05limit\x94G?\x84z\xe1G\xae\x14{uu\x8c\x04rule\x94\x8c\x0bfit_spectra\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cU/home/zknutson/PycharmProjects/snakemake-workflow-chandra/workflow/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/home/zknutson/PycharmProjects/snakemake-workflow-chandra');

# %%
import sherpa.astro.ui as sau
import matplotlib.pyplot as plt
from sherpa_contrib.chart import save_chart_spectrum
# Out:
# WARNING: imaging routines will not be available,
# failed to import sherpa.image.ds9_backend due to
# 'RuntimeErr: DS9Win unusable: Could not find ds9 on your PATH'

# %%
import logging
from pathlib import Path

import yaml
from astropy.table import Table

log = logging.getLogger(__name__)

YAML_DUMP_KWARGS = {
    "sort_keys": False,
    "indent": 4,
    "width": 80,
    "default_flow_style": False,
}


def convert_spectrum_chart_to_rdb(filename, overwrite=False):
    """Convert chart spectrum to rdb format"""
    data = Table.read(filename, format="ascii")
    data.rename_column("col1", "emin")
    data.rename_column("col2", "emax")
    data.rename_column("col3", "flux")

    filename_rdb = Path(filename).with_suffix(".rdb")

    log.info(f"Writing {filename_rdb}")
    data.write(filename_rdb, format="ascii.rdb", overwrite=overwrite)


def sherpa_parameter_to_dict(par):
    """Sherpa parameter to dict"""
    data = {}
    data["name"] = str(par.name)
    data["value"] = float(par.val)
    data["min"] = float(par.min)
    data["max"] = float(par.max)
    data["frozen"] = bool(par.frozen)
    data["unit"] = str(par.units)
    return data


def sherpa_model_to_dict(model):
    """Convert Sherpa model to dict"""
    data = {
        "name": model.name,
        "type": model.type,
    }

    if model.type == "binaryopmodel":
        data["operator"] = str(model.opstr)
        data["lhs"] = sherpa_model_to_dict(model.lhs)
        data["rhs"] = sherpa_model_to_dict(model.rhs)
        return data

    parameters = []

    for par in model.pars:
        data_par = sherpa_parameter_to_dict(par)
        parameters.append(data_par)

    data["parameters"] = parameters
    return data


def write_sherpa_model_to_yaml(model, filename, overwrite=True):
    """Write Sherpa model to YAML file"""
    data = sherpa_model_to_dict(model)

    if Path(filename).exists() and not overwrite:
        raise IOError(f"File exists: {filename}")

    with open(filename, "w") as fh:
        yaml.dump(data, fh, **YAML_DUMP_KWARGS)

    log.info(f"Writing {filename}")

# %%
sau.reset()

# %%
sau.show_all()

# %%
DATASET_IDS = [f"obs-id-{obs_id}" for obs_id in snakemake.config["obs_ids"]]

# %%
for dataset_id, filename in zip(DATASET_IDS, snakemake.input):
    sau.load_data(dataset_id, filename)
    sau.group_counts(dataset_id, 10)

sau.notice(0.5, 7)
# Out:
# read ARF file results/ACIS-all-500-7000/17508/spectra/pks-0637/ACIS-all-500-7000-17508-pks-0637.arf
# read RMF file results/ACIS-all-500-7000/17508/spectra/pks-0637/ACIS-all-500-7000-17508-pks-0637.rmf
# read ARF (background) file results/ACIS-all-500-7000/17508/spectra/pks-0637/ACIS-all-500-7000-17508-pks-0637_bkg.arf
# read RMF (background) file results/ACIS-all-500-7000/17508/spectra/pks-0637/ACIS-all-500-7000-17508-pks-0637_bkg.rmf
# read background file results/ACIS-all-500-7000/17508/spectra/pks-0637/ACIS-all-500-7000-17508-pks-0637_bkg.pi
# dataset obs-id-17508: 0.0073:14.9504 Energy (keV) (unchanged)
# read ARF file results/ACIS-all-500-7000/18688/spectra/pks-0637/ACIS-all-500-7000-18688-pks-0637.arf
# read RMF file results/ACIS-all-500-7000/18688/spectra/pks-0637/ACIS-all-500-7000-18688-pks-0637.rmf
# read ARF (background) file results/ACIS-all-500-7000/18688/spectra/pks-0637/ACIS-all-500-7000-18688-pks-0637_bkg.arf
# ...

# %%
sau.set_stat("cstat")
sau.set_method("simplex")

# %%
for dataset_id in DATASET_IDS:
    sau.set_source(dataset_id, sau.xsphabs.absgal * sau.powlaw1d.pwlsoft + sau.xsphabs.absclstr * sau.powlaw1d.pwlhard + sau.xsgaussian.feka)

sau.xsphabs.absgal.nh.val = 0.19
sau.xsphabs.absgal.nh.frozen = False

sau.powlaw1d.pwlsoft.gamma.val = 1.52
sau.powlaw1d.pwlsoft.ampl.val = 6e-5
sau.powlaw1d.pwlsoft.gamma.frozen = False
sau.powlaw1d.pwlsoft.ampl.frozen = False
sau.powlaw1d.pwlsoft.ref.val = 1

sau.xsphabs.absclstr.nh.val = 20.0
sau.xsphabs.absclstr.nh.frozen = False

sau.powlaw1d.pwlhard.gamma.val = 1.52
sau.powlaw1d.pwlhard.gamma.frozen = False
sau.powlaw1d.pwlhard.ampl.val = 5.2e-3
sau.powlaw1d.pwlhard.ampl.frozen = False
sau.powlaw1d.pwlhard.ref.val = 1

# %%
sau.xsgaussian.feka.LineE.val = 6.09
sau.xsgaussian.feka.LineE.frozen = False
sau.xsgaussian.feka.Sigma.val = 0.006
sau.xsgaussian.feka.Sigma.frozen = False
sau.xsgaussian.feka.norm.val = 1.5e-5
sau.xsgaussian.feka.norm.frozen = False

# %%
sau.fit()
# Out:
# WARNING: data set 'obs-id-17133' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17134' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17135' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17136' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17507' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17508' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17509' has associated backgrounds, but they have not been subtracted, nor have background models been set
# ...

# %%
for dataset_id in DATASET_IDS:
    sau.plot_fit_resid(dataset_id)
    plt.show()
# Out:
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# ...

# %%
sau.plot_bkg("obs-id-18871")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sau.plot_bkg("obs-id-18871")
#
# NameError: name 'sau' is not defined

# %%
for dataset_id in DATASET_IDS:
    sau.set_pileup_model(dataset_id, sau.jdpileup.jdp)

sau.jdpileup.jdp.f.min = 0.85
sau.jdpileup.jdp.ftime = 0.6
sau.jdpileup.jdp.fracexp = 0.987

# %%
sau.fit()
# Out:
# WARNING: data set 'obs-id-17133' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17134' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17135' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17136' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17507' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17508' has associated backgrounds, but they have not been subtracted, nor have background models been set
# WARNING: data set 'obs-id-17509' has associated backgrounds, but they have not been subtracted, nor have background models been set
# ...

# %%
for dataset_id in DATASET_IDS:
    sau.plot_fit_resid(dataset_id)
    plt.show()
# Out:
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# WARNING: The displayed errorbars have been supplied with the data or calculated using chi2xspecvar; the errors are not used in fits with cstat
# ...

# %%
for dataset_id in DATASET_IDS:
    sau.set_analysis(dataset_id, "energy", "rate", factor=1)

e_min = 0.5
e_max = 7

save_chart_spectrum(
        str(snakemake.output[0]), elow=e_min, ehigh=e_max, clobber=True, id=DATASET_IDS[0]
)
# Out:
# dataset obs-id-17508: 0.0073:7.0226 Energy (keV)
# dataset obs-id-18688: 0.0073:7.008 Energy (keV)
# dataset obs-id-18871: 0.0073:7.008 Energy (keV)
# dataset obs-id-17133: 0.0073:7.008 Energy (keV)
# dataset obs-id-17510: 0.0073:7.0226 Energy (keV)
# dataset obs-id-17509: 0.0073:7.008 Energy (keV)
# dataset obs-id-17513: 0.0073:7.008 Energy (keV)
# dataset obs-id-17512: 0.0073:7.008 Energy (keV)
# dataset obs-id-17507: 0.0073:7.0372 Energy (keV)
# dataset obs-id-17514: 0.0073:7.008 Energy (keV)
# dataset obs-id-17135: 0.0073:7.0226 Energy (keV)
# dataset obs-id-17136: 0.0073:7.0518 Energy (keV)
# dataset obs-id-19996: 0.0073:7.008 Energy (keV)
# dataset obs-id-19989: 0.0073:7.0226 Energy (keV)
# dataset obs-id-17511: 0.0073:7.0518 Energy (keV)
# dataset obs-id-20077: 0.0073:7.008 Energy (keV)
# dataset obs-id-17134: 0.0073:7.0226 Energy (keV)
# dataset obs-id-20079: 0.0073:7.0226 Energy (keV)
# ...

# %%
write_sherpa_model_to_yaml(sau.get_source(id=DATASET_IDS[0]), filename=str(snakemake.output[1]))
